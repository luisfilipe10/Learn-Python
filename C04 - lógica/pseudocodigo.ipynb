# %%
n1 = float(input('Insira a nota 1: '))
n2 = float(input('Insira a nota 2: '))
n3 = float(input('Insira a nota 3: '))

print('notas recebidas...')

media = (n1+n2+n3) /3

print(f'a media das notas é {media} ')
# Out:
# notas recebidas...
# a media das notas é 5.833333333333333
